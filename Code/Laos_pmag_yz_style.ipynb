# %% [markdown]
# # Notebook for Laos Basalts

# %% [markdown]
# This notebook includes data from insitu basalt flows and exsitu conglomerates interpreted by Sieh et al. 2020 as ejecta that were impacted by the Australasian bolide in southern Laos

# %% [markdown]
# ### Laos Basalt sample descriptions:

# %% [markdown]
# + no bedding orientations were taken for most sites as they are either near horizontal flows or conglomerates
#
# + minimal to significant weathering rinds and laterite present on most sampled basalts due to high humidity and monsoon rains
# + diamicton refers to a massive loess/airfall deposit that has been associated with regional fires and associated with bollide due to presence of tektites
#
# + all ages are Ar/Ar from Sieh et al. 2020 and
#
# + site NWFA is 5 block samples from a supposed insitu flow aged 518 ± 6 ka
#
# + site NWFB is 3 block samples, no sun, from a supposed insitu flow ages 936 30 ka
#
# + site NWFC is 8 block samples of supposed ejecta boulders in diamicton thought to be between 800-1397 ka
#
# + site PKQA is 10 core samples of supposed ejecta boulders in diamicton thought to be between 800-1397 ka. These cores are from the same boulder: Core 1,2 | Core 3,4 | Core 5,6 | Core 7,8,9,0
#
# + site PKSB is 1 block sample from a truly insitu cohernt basalt flow thought to be "shockwave brecciated" aged ~1000 ka
#
# + site PKSF is 11 core samples of supposed ejecta boulders in diamicton thought to be between 800-1397 ka
#
# + site PKSG is 8 block samples, no sun, of supposed ejecta boulders in diamicton thought to be between 800-1397 ka
#
# + site PKSH is 3 core samples, H1 and H2 (aged a little older than 770 ± 8 ka) are in the same horizon 5m above H3 and 12m west. Thought to capture Brunhes-Matuyama reversal at ~780 ka
#
# + site PKSI is 1 block sample from a questionally insitu corestone aged 553 ± 20 ka
#
# + site PKSJ is 3 cores samples, no sun, from supposed insitu basalt flow potentially with pahoehoe lobes and columnar jointing. aged 601 ± 44 ka
#
# + site PKSK is 3 core samples, no sun, from  supposed insitu basalt flow from a nearby scoria cone aged 407 ±  18 ka
#
# + site WBEA is 2 block samples, no sun, from a massive basalt flow to be used as basalt stratigraphic control. Best outcrop. aged 1397 ka

# %%
### Thermal Demagnetization descriptions:

# %% [markdown]
# + LN2 step removed some PDF overprint, but in many samples little change was seen
#
# + site NWFA has a large pdf overprint that was removed by 400 C. The mt component is well typically between 530 C to 580 C. There is a component that keeps unblocking up above 580. This could be a maghemite or hematite carried component that is a VRM of PDF. But the data is too noisy to make fits. We do not anchor the mt fits.
#
# + site NWFB has a pdf overprint that was removed by 200 C. The mt component is well typically between 500 C to 580 C. There is a component that keeps unblocking up above 580. This could be a maghemite or hematite carried component that is a VRM of PDF. But the data is too noisy to make fits. We do not anchor the mt fits.
#
# + site NWFC has a large pdf overprint that was removed by 400 C. The mt component is well typically between 530 C to 580 C. There is a component that keeps unblocking up above 580. This could be a maghemite or hematite carried component that is a VRM of PDF. But the data is too noisy to make fits. We do not anchor the mt fits.
#
# + site PKQA has a pdf overprint that was removed by 200 C. The mt component is well typically between 500 C to 580 C. There is a component that keeps unblocking up above 580. This could be a maghemite or hematite carried component that is a VRM of PDF. But the data is too noisy to make fits. We do not anchor the mt fits.
#
# + site PKSB has a large pdf overprint that was removed by 400 C. The mt component is well typically between 530 C to 580 C. There is a component that keeps unblocking up above 580. This could be a maghemite or hematite carried component that is a VRM of PDF. But the data is too noisy to make fits. We do not anchor the mt fits.
#
# + site PKSF has a pdf overprint that was removed by 200 C. The mt component is well typically between 500 C to 580 C. There is a component that keeps unblocking up above 580. This could be a maghemite or hematite carried component that is a VRM of PDF. But the data is too noisy to make fits. We do not anchor the mt fits.
#
# + site PKSG has a large pdf overprint that was removed by 400 C. The mt component is well typically between 530 C to 580 C. There is a component that keeps unblocking up above 580. This could be a maghemite or hematite carried component that is a VRM of PDF. But the data is too noisy to make fits. We do not anchor the mt fits.
#
# + site PKSH has a pdf overprint that was removed by 200 C. The mt component is well typically between 500 C to 580 C. There is a component that keeps unblocking up above 580. This could be a maghemite or hematite carried component that is a VRM of PDF. But the data is too noisy to make fits. We do not anchor the mt fits.
#
# + site PKSI was both demagnetized in a and b series. It has overall nicely resolved pdf. But the directions do not differ much from the pdf throughout the demagnetization. In geographic coordinates the directions are typically similar to the pdf direction! On the M/M0 plot, the decay of remanence near magnetite unblocking temperature is not very significant. This sill is probabbly quite heavily altered. We do not make mt fits in this site.
#
# + site PKSJ was both demagnetized in a and b series. It has a large pdf overprint, LN2 demagnetized ~ 90% of the remanence in some specimens. Little remanence is left and in bedding coordinates the directions are inconsistent between the specimens. We do not make mt fits in this site.
#
# + site PKSK was both demagnetized in a and b series. LN2 removed ~80% of remanence in some specimens but did not help isolating the primary component. Only a couple of specimens preserved a small, noisy primary component (5-3a and 5-5a) in a series but it is too noisy in the b series.
#
# + site WBEA was demagnetized in a series only. It has a consistent, strong primary mt component that we interpret as the primary emplacement component ca. 1098 Ma. There is a high temperature component beyond 580 C. This could be a maghemite or hematite carried component that is a VRM of PDF. But the data is too noisy to make fits. We do not anchor the mt fits.
#
# ==== SWILLP EXAMPLES ====
#
# site CS7 has a large pdf. This overprint component can be removed by liquid nitrogen dunk and heating up to ~250 C. Only two specimens (4 and 5 in both a and b series) have a primary component unblocking ca. 500-580 C. In both series these two samples give similar fitted directions. Other samples have largely been completely overprinted such that a direction similar to those of -4 and -5 is hinted in the thermal demag steps but not resolved.
#
# site CS8 was demagnetized in a series only. It has a pdf component that can be removed by up to 475 C, followed by by nice consistent sharply unblocking primary magnetite component from ~530 C to 580 C. There is an additional higher temperature component that is not well resolved.
#
# site CS9 was both demagnetized in a and b series. It has a large pdf overprint that can be removed by LN2 dunk and heating up to ~150-250 C. It looks like the a series without liquid nitrogen dunk is resulted in cleaner data than the b series. This could be due to the b series containing more end chips and thus have overall weaker total magnetization than a series specimens. Another possibility which I think is more likely is that the liquid nitrogen dunk actually resulted in randomization of the magnetite grains that carry the higher temperature component magnetization which in this case caused noise that has high ratios in intensity relative to the signal. This resulted in only three specimens having interpretable mt component in the b series versus 5 in the a series. We use a series data for the mt fits.
#
# site CS10 was both demagnetized in a and b series. It has a pdf component that can be removed largely by LN2 dunk or by heating up to 300-400 C. It appears to have a consistent easterly overprint component that unblocks through magnetite Curie temperature.
#
# site CS11 was both demagnetized in a and b series. It doesn't have consistent site level directions. A few specimens have an easterly overprint component that unblocks through magnetite Curie temperature similar to those in site CS10.
#
# site CS12 was both demagnetized in a and b series. It has a large pdf overprint that can be removed largely by LN2 dunk or by heating up to 300-400 C. LN2 helps removing the PDF overprint component and more specimens yielded interpretable mt components.
#
# site CS13 was both demagnetized in a and b series. It has a large pdf overprint that can be removed by LN2 dunk and heating up to ~150-250 C. It looks like the a series without liquid nitrogen dunk is resulted in cleaner data than the b series. This could be similar to site CS9.
#
# site CS14 was both demagnetized in a and b series. It does not have very consistent directions except for a lt component.
#
# site CS15 was both demagnetized in a and b series. It has a large pdf overprint that can be removed by LN2 dunk and heating up to ~250-400 C. There is not a consistent component that can be fitted through higher temperatures.

# %% [markdown]
# ### import libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors as colors

from matplotlib.patches import Patch
from matplotlib.lines import Line2D

import cartopy.crs as ccrs
import cartopy.feature as cfeature

import pmagpy.pmag as pmag
import pmagpy.ipmag as ipmag

from IPython.display import display

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# /Users/nicolasanderson/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ### load MagIC data files

# %%
Laos_site_locations = pd.read_csv('/Users/nicolasanderson/Documents/GitHub/2024_Laos_Australasian_Impactor/Magnetometer_Data_corrected/locations.txt', sep='\t', header=1)
Laos_site_data = pd.read_csv('/Users/nicolasanderson/Documents/GitHub/2024_Laos_Australasian_Impactor/Magnetometer_Data_corrected/sites.txt', sep='\t', header=1)
Laos_specimen_data = pd.read_csv('/Users/nicolasanderson/Documents/GitHub/2024_Laos_Australasian_Impactor/Magnetometer_Data_corrected/specimens.txt', sep='\t', header=1)
Laos_measurement_data = pd.read_csv('/Users/nicolasanderson/Documents/GitHub/2024_Laos_Australasian_Impactor/Magnetometer_Data_corrected/measurements.txt', sep='\t', header=1)

# %%
Laos_site_data
# Out:
#     site location                                            samples  \
# 0   NWFA     NWFA  NWFA-1B:NWFA-1C:NWFA-1D:NWFA-1E:NWFA-1F:NWFA-1...
# 1   NWFA     NWFA  NWFA-1B:NWFA-1C:NWFA-1D:NWFA-1E:NWFA-1F:NWFA-1...
# 2   NWFB     NWFB  NWFB-1B:NWFB-1C:NWFB-1D:NWFB-1E:NWFB-1F:NWFB-1...
# 3   NWFB     NWFB  NWFB-1B:NWFB-1C:NWFB-1D:NWFB-1E:NWFB-1F:NWFB-1...
# 4   NWFC     NWFC  NWFC-1B:NWFC-1C:NWFC-2B:NWFC-2C:NWFC-2D:NWFC-2...
# 5   NWFC     NWFC  NWFC-1B:NWFC-1C:NWFC-2B:NWFC-2C:NWFC-2D:NWFC-2...
# 6   PKQA     PKQA  PKQA-0A:PKQA-0B:PKQA-0C:PKQA-0E:PKQA-0F:PKQA-1...
# 7   PKQA     PKQA                            PKQA-0D:PKQA-0E:PKQA-0F
# 8   PKQA     PKQA  PKQA-0A:PKQA-0B:PKQA-0C:PKQA-0D:PKQA-0E:PKQA-0...
# 9   PKSB     PKSB                                             PKSB-1
# 10  PKSB     PKSB                                             PKSB-1
# 11  PKSF     PKSF  PKSF-0A:PKSF-0B:PKSF-0C:PKSF-0D:PKSF-0E:PKSF-0...
# 12  PKSF     PKSF  PKSF-0A:PKSF-0B:PKSF-0C:PKSF-0D:PKSF-0E:PKSF-0...
# ...

# %%
Laos_site_locations
# Out:
#     analysts   citations  lat_n  lat_s location  lon_e  lon_w
# 0        NaN  This study   15.2   15.2     PKSH  106.2  106.2
# 1        NaN  This study   15.2   15.2     PKSG  106.2  106.2
# 2        NaN  This study   15.1   15.1     PKSF  106.2  106.2
# 3        NaN  This study   15.2   15.2     PKSI  106.2  106.2
# 4        NaN  This study   15.3   15.3     WBEA  106.3  106.3
# 5        NaN  This study   15.2   15.2     PKSK  106.3  106.3
# 6        NaN  This study   15.2   15.2     PKSB  106.2  106.2
# 7        NaN  This study   15.2   15.2     PKSJ  106.3  106.3
# 8        NaN  This study   15.4   15.4     NWFC  106.1  106.1
# 9        NaN  This study   15.6   15.6     NWFB  106.0  106.0
# 10       NaN  This study   15.1   15.1     PKQA  105.8  105.8
# 11       NaN  This study   15.6   15.6     NWFA  106.1  106.1

# %%
Laos_specimen_data
# Out:
#      specimen       experiments   sample  dir_alpha95 dir_comp  dir_dec  \
# 0     NWFA-1A               NaN   NWFA-1          NaN      NaN      NaN
# 1     NWFA-1A               NaN  NWFA-1A          NaN      NaN      NaN
# 2     NWFA-1B  NWFA-1B_LP-DIR-T  NWFA-1B          NaN       mt      9.2
# 3     NWFA-1B  NWFA-1B_LP-DIR-T  NWFA-1B          NaN       lt    329.5
# 4     NWFA-1B               NaN   NWFA-1          NaN      NaN      NaN
# ...       ...               ...      ...          ...      ...      ...
# 1618  WBEA-2D               NaN  WBEA-2D          NaN      NaN      NaN
# 1619  WBEA-2D               NaN   WBEA-2          NaN      NaN      NaN
# 1620  WBEA-2D  WBEA-2D_LP-DIR-T   WBEA-2          NaN       lt    131.3
# 1621  WBEA-2E               NaN   WBEA-2          NaN      NaN      NaN
# 1622  WBEA-2E               NaN  WBEA-2E          NaN      NaN      NaN
#
#       dir_inc  dir_n_comps  dir_n_measurements  dir_tilt_correction  ...  \
# ...

# %% [markdown]
# ### core direction plots

# %%
# let's first calculate pdf at Laos

Laos_lat, Laos_lon = 15.28, 106.16
Laos_pdf_dec, Laos_pdf_inc, _ = ipmag.igrf([2024, 0, Laos_lat, Laos_lon])
Laos_pdf_dec, Laos_pdf_inc

# let's first calculate pdf at Laos

Laos_lat, Laos_lon = 15.28, 106.16
Laos_pdf_dec_r, Laos_pdf_inc_r, _ = ipmag.igrf([2000, 0, Laos_lat, Laos_lon])
Laos_pdf_dec_r, Laos_pdf_inc_r
# Out:
# (np.float64(359.5591339257837), np.float64(16.95070818377873))

# %% [markdown]
# ### lt component

# %%
# get the lt component
Laos_thermal_demag_lt_geo = Laos_site_data[(Laos_site_data['dir_comp_name']=='lt') & 
                                                    (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

# %%
# plot a series pdf means
plt.figure(figsize=(4,4))
ipmag.plot_net()

for i in range(len(Laos_thermal_demag_lt_geo)):
    ipmag.plot_di_mean(Laos_thermal_demag_lt_geo['dir_dec'][i], 
                       Laos_thermal_demag_lt_geo['dir_inc'][i], 
                       Laos_thermal_demag_lt_geo['dir_alpha95'][i], markersize=5, color='g')

ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_di(Laos_pdf_dec_r, Laos_pdf_inc_r, marker='*', markersize=100, color='r', zorder=100)

# plt.savefig('code_output/Laos_PDF_a_series.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### mt component directions

# %% [markdown]
# + interpreted primary direction for all insitu flow sites with ages
# + sites include NWFA, NWFB, PKSB, PKSH 1&2, PKSI, PKSJ, PKSK, WBEA
# + sites with few specimens and high disperision wil be removed. those sites are:

# %%
# NWFA data with no tilt correction
NWFA_mt_spec = Laos_specimen_data[(Laos_specimen_data['location']=='NWFA') &
 (Laos_specimen_data['dir_tilt_correction']==0) &
 (Laos_specimen_data['dir_comp']=='mt')].reset_index(drop=1)
NWFA_mt_site = Laos_site_data[(Laos_site_data['location']=='NWFA') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

# NWFB data with no tilt correction
NWFB_mt_spec = Laos_specimen_data[(Laos_specimen_data['location']=='NWFB') &
 (Laos_specimen_data['dir_tilt_correction']==0) &
 (Laos_specimen_data['dir_comp']=='mt')].reset_index(drop=1)
NWFB_mt_site = Laos_site_data[(Laos_site_data['location']=='NWFB') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

 # NWFC data with no tilt correction
NWFC_mt_spec = Laos_specimen_data[(Laos_specimen_data['location']=='NWFC') &
 (Laos_specimen_data['dir_tilt_correction']==0) &
 (Laos_specimen_data['dir_comp']=='mt')].reset_index(drop=1)
NWFC_mt_site = Laos_site_data[(Laos_site_data['location']=='NWFC') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

# PKQA data with no tilt correction
PKQA_mt_spec = Laos_specimen_data[(Laos_specimen_data['location']=='PKQA') &
 (Laos_specimen_data['dir_tilt_correction']==0) &
 (Laos_specimen_data['dir_comp']=='mt')].reset_index(drop=1)
PKQA_mt_site = Laos_site_data[(Laos_site_data['location']=='PKQA') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

# PKSB data with no tilt correction
PKSB_mt_spec = Laos_specimen_data[(Laos_specimen_data['location']=='PKSB') &
 (Laos_specimen_data['dir_tilt_correction']==0) &
 (Laos_specimen_data['dir_comp']=='mt')].reset_index(drop=1)
PKSB_mt_site = Laos_site_data[(Laos_site_data['location']=='PKSB') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

 # PKSF data with no tilt correction
PKSF_mt_spec = Laos_specimen_data[(Laos_specimen_data['location']=='PKSF') &
 (Laos_specimen_data['dir_tilt_correction']==0) &
 (Laos_specimen_data['dir_comp']=='mt')].reset_index(drop=1)
PKSF_mt_site = Laos_site_data[(Laos_site_data['location']=='PKSF') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

# PKSG data with no tilt correction
PKSG_mt_spec = Laos_specimen_data[(Laos_specimen_data['location']=='PKSG') &
 (Laos_specimen_data['dir_tilt_correction']==0) &
 (Laos_specimen_data['dir_comp']=='mt')].reset_index(drop=1)
PKSG_mt_site = Laos_site_data[(Laos_site_data['location']=='PKSG') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)


# PKSH data with no tilt correction
PKSH_mt_spec = Laos_specimen_data[(Laos_specimen_data['location']=='PKSH') &
 (Laos_specimen_data['dir_tilt_correction']==0) &
 (Laos_specimen_data['dir_comp']=='mt')].reset_index(drop=1)
PKSH_mt_site = Laos_site_data[(Laos_site_data['location']=='PKSH') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

# PKSI data with no tilt correction
PKSI_mt_spec = Laos_specimen_data[(Laos_specimen_data['location']=='PKSI') &
 (Laos_specimen_data['dir_tilt_correction']==0) &
 (Laos_specimen_data['dir_comp']=='mt')].reset_index(drop=1)
PKSI_mt_site = Laos_site_data[(Laos_site_data['location']=='PKSI') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

# PKSJ data with no tilt correction
PKSJ_mt_spec = Laos_specimen_data[(Laos_specimen_data['location']=='PKSJ') &
 (Laos_specimen_data['dir_tilt_correction']==0) &
 (Laos_specimen_data['dir_comp']=='mt')].reset_index(drop=1)
PKSJ_mt_site = Laos_site_data[(Laos_site_data['location']=='PKSJ') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

# PKSK data with no tilt correction
PKSK_mt_spec = Laos_specimen_data[(Laos_specimen_data['location']=='PKSK') &
 (Laos_specimen_data['dir_tilt_correction']==0) &
 (Laos_specimen_data['dir_comp']=='mt')].reset_index(drop=1)
PKSK_mt_site = Laos_site_data[(Laos_site_data['location']=='PKSK') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

# WBEA data with no tilt correction
WBEA_mt_spec = Laos_specimen_data[(Laos_specimen_data['location']=='WBEA') &
 (Laos_specimen_data['dir_tilt_correction']==0) &
 (Laos_specimen_data['dir_comp']=='mt')].reset_index(drop=1)
WBEA_mt_site = Laos_site_data[(Laos_site_data['location']=='WBEA') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

# %%
 # we need the geographic coordinates of the site mean directions 

NWFA_mt_site_gc = Laos_site_data[(Laos_site_data['location']=='NWFA') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

NWFB_mt_site_gc = Laos_site_data[(Laos_site_data['location']=='NWFB') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

NWFC_mt_site_gc = Laos_site_data[(Laos_site_data['location']=='NWFC') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

PKQA_mt_site_gc = Laos_site_data[(Laos_site_data['location']=='PKQA') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

PKSB_mt_site_gc = Laos_site_data[(Laos_site_data['location']=='PKSB') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

PKSF_mt_site_gc = Laos_site_data[(Laos_site_data['location']=='PKSF') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

PKSG_mt_site_gc = Laos_site_data[(Laos_site_data['location']=='PKSG') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

PKSH_mt_site_gc = Laos_site_data[(Laos_site_data['location']=='PKSH') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

PKSI_mt_site_gc = Laos_site_data[(Laos_site_data['location']=='PKSI') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

PKSJ_mt_site_gc = Laos_site_data[(Laos_site_data['location']=='PKSJ') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

PKSK_mt_site_gc = Laos_site_data[(Laos_site_data['location']=='PKSK') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

WBEA_mt_site_gc = Laos_site_data[(Laos_site_data['location']=='WBEA') &
 (Laos_site_data['dir_comp_name']=='mt') &
 (Laos_site_data['dir_tilt_correction']==0)].reset_index(drop=1)

# %% [markdown]
# ### NWFA mt directions

# %%
plt.figure(figsize=(4,4))
ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_net()
ipmag.plot_di(NWFA_mt_spec['dir_dec'], NWFA_mt_spec['dir_inc'], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(NWFA_mt_site['dir_dec'][0], NWFA_mt_site['dir_inc'][0], NWFA_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')

# %%
ax = ipmag.make_orthographic_map(150, 40, figsize=(4,4))
ipmag.plot_pole_dp_dm(ax, NWFA_mt_site['vgp_lon'][0], NWFA_mt_site['vgp_lat'][0], 
                      slon=Laos_lon, slat=Laos_lat, 
                      dp=NWFA_mt_site['vgp_dp'][0], dm=NWFA_mt_site['vgp_dm'][0], 
                      pole_color='red', pole_marker='^', pole_edgecolor = None, markersize=50, pole_label='NWFA (518 ± 6 ka (or 740 ka)',
                      site_color=None, site_edgecolor=None, site_marker=None, site_label=None)

plt.legend(loc=8, fontsize=12)
plt.show()

# %% [markdown]
# ### NWFB mt directions

# %%
NWFB_mt_site
# Out:
#    site location                                            samples  \
# 0  NWFB     NWFB  NWFB-1B:NWFB-1C:NWFB-1D:NWFB-1E:NWFB-1F:NWFB-1...
#
#                                            specimens  dir_alpha95  \
# 0  NWFB-1B:NWFB-1C:NWFB-1D:NWFB-1E:NWFB-1F:NWFB-1...         16.9
#
#   dir_comp_name  dir_dec  dir_inc  dir_k  dir_n_samples  ...  analysts  \
# 0            mt     81.8    -60.9    5.0             20  ...       NaN
#
#    criteria              software_packages   citations  \
# 0    ACCEPT  pmagpy-4.3.7: demag_gui.v.3.0  This study
#
#                                         method_codes  result_quality  vgp_dm  \
# 0  SO-CMD-NORTH:LP-DIR-T:DE-BFL:DA-DIR-GEO:LP-DC4...               g    25.9
#
#    vgp_dp  vgp_lat vgp_lon
# 0    19.8     -4.4   238.4
#
# [1 rows x 28 columns]

# %%
plt.figure(figsize=(4,4))
ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_net()
ipmag.plot_di(NWFB_mt_spec['dir_dec'], NWFB_mt_spec['dir_inc'], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(NWFB_mt_site['dir_dec'][0], NWFB_mt_site['dir_inc'][0], NWFB_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')

# %%
ax = ipmag.make_orthographic_map(160, 20, figsize=(4,4))
ipmag.plot_pole_dp_dm(ax, NWFB_mt_site['vgp_lon'][0], NWFB_mt_site['vgp_lat'][0], 
                      slon=Laos_lon, slat=Laos_lat, 
                      dp=NWFB_mt_site['vgp_dp'][0], dm=NWFB_mt_site['vgp_dm'][0], 
                      pole_color='red', pole_marker='^', pole_edgecolor = None, markersize=50, pole_label='NWFB (936 ± 30 ka)',
                      site_color=None, site_edgecolor=None, site_marker=None, site_label=None)

plt.legend(loc=8, fontsize=12)
plt.show()

# %% [markdown]
# ### NWFC mt directions

# %%
plt.figure(figsize=(4,4))
ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_net()
ipmag.plot_di(NWFC_mt_spec['dir_dec'], NWFC_mt_spec['dir_inc'], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(NWFC_mt_site['dir_dec'][0], NWFC_mt_site['dir_inc'][0], NWFC_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')

# %%
ax = ipmag.make_orthographic_map(150, 40, figsize=(4,4))
ipmag.plot_pole_dp_dm(ax, NWFC_mt_site['vgp_lon'][0], NWFC_mt_site['vgp_lat'][0], 
                      slon=Laos_lon, slat=Laos_lat, 
                      dp=NWFC_mt_site['vgp_dp'][0], dm=NWFC_mt_site['vgp_dm'][0], 
                      pole_color='red', pole_marker='^', pole_edgecolor = None, markersize=50, pole_label='NWFC (Conglomerate)',
                      site_color=None, site_edgecolor=None, site_marker=None, site_label=None)

plt.legend(loc=8, fontsize=12)
plt.show()

# %% [markdown]
# ### PKQA mt directions

# %%
plt.figure(figsize=(4,4))
ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_net()
ipmag.plot_di(PKQA_mt_spec['dir_dec'], PKQA_mt_spec['dir_inc'], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(PKQA_mt_site['dir_dec'][0], PKQA_mt_site['dir_inc'][0], PKQA_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')

# %%
ax = ipmag.make_orthographic_map(150, -20, figsize=(4,4))
ipmag.plot_pole_dp_dm(ax, PKQA_mt_site['vgp_lon'][0], PKQA_mt_site['vgp_lat'][0], 
                      slon=Laos_lon, slat=Laos_lat, 
                      dp=PKQA_mt_site['vgp_dp'][0], dm=PKQA_mt_site['vgp_dm'][0], 
                      pole_color='red', pole_marker='^', pole_edgecolor = None, markersize=50, pole_label='PKQA (Conglomerate)',
                      site_color=None, site_edgecolor=None, site_marker=None, site_label=None)

plt.legend(loc=8, fontsize=12)
plt.show()

# %% [markdown]
# ### PKSB mt directions

# %%
plt.figure(figsize=(4,4))
ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_net()
ipmag.plot_di(PKSB_mt_spec['dir_dec'], PKSB_mt_spec['dir_inc'], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(PKSB_mt_site['dir_dec'][0], PKSB_mt_site['dir_inc'][0], PKSB_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')

# %%
ax = ipmag.make_orthographic_map(150, -50, figsize=(4,4))
ipmag.plot_pole_dp_dm(ax, PKSB_mt_site['vgp_lon'][0], PKSB_mt_site['vgp_lat'][0], 
                      slon=Laos_lon, slat=Laos_lat, 
                      dp=PKSB_mt_site['vgp_dp'][0], dm=PKSB_mt_site['vgp_dm'][0], 
                      pole_color='red', pole_marker='^', pole_edgecolor = None, markersize=50, pole_label='PKSB (906 ± 12 ka)',
                      site_color=None, site_edgecolor=None, site_marker=None, site_label=None)

plt.legend(loc=1, fontsize=12)
plt.show()

# %% [markdown]
# ### PKSF mt directions

# %%
plt.figure(figsize=(4,4))
ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_net()
ipmag.plot_di(PKSF_mt_spec['dir_dec'], PKSF_mt_spec['dir_inc'], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(PKSF_mt_site['dir_dec'][0], PKSF_mt_site['dir_inc'][0], PKSF_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')

# %%
ax = ipmag.make_orthographic_map(150, 40, figsize=(4,4))
ipmag.plot_pole_dp_dm(ax, PKSF_mt_site['vgp_lon'][0], PKSF_mt_site['vgp_lat'][0], 
                      slon=Laos_lon, slat=Laos_lat, 
                      dp=PKSF_mt_site['vgp_dp'][0], dm=PKSF_mt_site['vgp_dm'][0], 
                      pole_color='red', pole_marker='^', pole_edgecolor = None, markersize=50, pole_label='PKSF (Conglomerate)',
                      site_color=None, site_edgecolor=None, site_marker=None, site_label=None)

plt.legend(loc=8, fontsize=12)
plt.show()

# %% [markdown]
# ### PKSG mt directions

# %%
plt.figure(figsize=(4,4))
ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_net()
ipmag.plot_di(PKSG_mt_spec['dir_dec'], PKSG_mt_spec['dir_inc'], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(PKSG_mt_site['dir_dec'][0], PKSG_mt_site['dir_inc'][0], PKSG_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')

# %%
ax = ipmag.make_orthographic_map(150, -40, figsize=(4,4))
ipmag.plot_pole_dp_dm(ax, PKSG_mt_site['vgp_lon'][0], PKSG_mt_site['vgp_lat'][0], 
                      slon=Laos_lon, slat=Laos_lat, 
                      dp=PKSG_mt_site['vgp_dp'][0], dm=PKSG_mt_site['vgp_dm'][0], 
                      pole_color='red', pole_marker='^', pole_edgecolor = None, markersize=50, pole_label='PKSG (Conglomerate)',
                      site_color=None, site_edgecolor=None, site_marker=None, site_label=None)

plt.legend(loc=1, fontsize=12)
plt.show()

# %% [markdown]
# ### PKSH mt directions

# %%
plt.figure(figsize=(4,4))
ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_net()
ipmag.plot_di(PKSH_mt_spec['dir_dec'], PKSH_mt_spec['dir_inc'], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(PKSH_mt_site['dir_dec'][0], PKSH_mt_site['dir_inc'][0], PKSH_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')

# %%
ax = ipmag.make_orthographic_map(150, -40, figsize=(4,4))
ipmag.plot_pole_dp_dm(ax, PKSH_mt_site['vgp_lon'][0], PKSH_mt_site['vgp_lat'][0], 
                      slon=Laos_lon, slat=Laos_lat, 
                      dp=PKSH_mt_site['vgp_dp'][0], dm=PKSH_mt_site['vgp_dm'][0], 
                      pole_color='red', pole_marker='^', pole_edgecolor = None, markersize=50, pole_label='PKSH (~ 770 ± 9.3 ka)',
                      site_color=None, site_edgecolor=None, site_marker=None, site_label=None)

plt.legend(loc=1, fontsize=12)
plt.show()

# %% [markdown]
# ### PKSI mt directions

# %%
plt.figure(figsize=(4,4))
ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_net()
ipmag.plot_di(PKSI_mt_spec['dir_dec'], PKSI_mt_spec['dir_inc'], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(PKSI_mt_site['dir_dec'][0], PKSI_mt_site['dir_inc'][0], PKSI_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')

# %%
ax = ipmag.make_orthographic_map(160, 20, figsize=(4,4))
ipmag.plot_pole_dp_dm(ax, PKSI_mt_site['vgp_lon'][0], PKSI_mt_site['vgp_lat'][0], 
                      slon=Laos_lon, slat=Laos_lat, 
                      dp=PKSI_mt_site['vgp_dp'][0], dm=PKSI_mt_site['vgp_dm'][0], 
                      pole_color='red', pole_marker='^', pole_edgecolor = None, markersize=50, pole_label='PKSI (553 ± 20 ka)',
                      site_color=None, site_edgecolor=None, site_marker=None, site_label=None)

plt.legend(loc=8, fontsize=12)
plt.show()

# %% [markdown]
# ### PKSJ mt directions

# %%
plt.figure(figsize=(4,4))
ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_net()
ipmag.plot_di(PKSJ_mt_spec['dir_dec'], PKSJ_mt_spec['dir_inc'], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(PKSJ_mt_site['dir_dec'][0], PKSJ_mt_site['dir_inc'][0], PKSJ_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')

# %%
ax = ipmag.make_orthographic_map(150, -40, figsize=(4,4))
ipmag.plot_pole_dp_dm(ax, PKSJ_mt_site['vgp_lon'][0], PKSJ_mt_site['vgp_lat'][0], 
                      slon=Laos_lon, slat=Laos_lat, 
                      dp=PKSJ_mt_site['vgp_dp'][0], dm=PKSJ_mt_site['vgp_dm'][0], 
                      pole_color='red', pole_marker='^', pole_edgecolor = None, markersize=50, pole_label='PKSJ (601 ± 44 ka)',
                      site_color=None, site_edgecolor=None, site_marker=None, site_label=None)

plt.legend(loc=1, fontsize=12)
plt.show()

# %% [markdown]
# ### PKSK mt directions

# %%
plt.figure(figsize=(4,4))
ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_net()
ipmag.plot_di(PKSK_mt_spec['dir_dec'], PKSK_mt_spec['dir_inc'], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(PKSK_mt_site['dir_dec'][0], PKSK_mt_site['dir_inc'][0], PKSK_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')

# %%
ax = ipmag.make_orthographic_map(150, -50, figsize=(4,4))
ipmag.plot_pole_dp_dm(ax, PKSK_mt_site['vgp_lon'][0], PKSK_mt_site['vgp_lat'][0], 
                      slon=Laos_lon, slat=Laos_lat, 
                      dp=PKSK_mt_site['vgp_dp'][0], dm=PKSK_mt_site['vgp_dm'][0], 
                      pole_color='red', pole_marker='^', pole_edgecolor = None, markersize=50, pole_label='PKSK (407 ± 18 ka)',
                      site_color=None, site_edgecolor=None, site_marker=None, site_label=None)

plt.legend(loc=1, fontsize=12)
plt.show()

# %% [markdown]
# ### WBEA mt directions

# %%
plt.figure(figsize=(4,4))
ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_net()
ipmag.plot_di(WBEA_mt_spec['dir_dec'], WBEA_mt_spec['dir_inc'], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(WBEA_mt_site['dir_dec'][0], WBEA_mt_site['dir_inc'][0], WBEA_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')

# %%
ax = ipmag.make_orthographic_map(150, -40, figsize=(4,4))
ipmag.plot_pole_dp_dm(ax, WBEA_mt_site['vgp_lon'][0], WBEA_mt_site['vgp_lat'][0], 
                      slon=Laos_lon, slat=Laos_lat, 
                      dp=WBEA_mt_site['vgp_dp'][0], dm=WBEA_mt_site['vgp_dm'][0], 
                      pole_color='red', pole_marker='^', pole_edgecolor = None, markersize=50, pole_label='WBEA (1397 ka)',
                      site_color=None, site_edgecolor=None, site_marker=None, site_label=None)

plt.legend(loc=1, fontsize=12)
plt.show()

# %% [markdown]
# ### summarize mt component site mean directions

# %%
plt.figure(figsize=(4,4))
ipmag.plot_net()
ipmag.plot_di_mean(NWFA_mt_site['dir_dec'][0], NWFA_mt_site['dir_inc'][0], NWFA_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(NWFB_mt_site['dir_dec'][0], NWFB_mt_site['dir_inc'][0], NWFB_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')
#ipmag.plot_di_mean(NWFC_mt_site['dir_dec'][0], NWFC_mt_site['dir_inc'][0], NWFC_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')
#ipmag.plot_di_mean(PKQA_mt_site['dir_dec'][0], PKQA_mt_site['dir_inc'][0], PKQA_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(PKSB_mt_site['dir_dec'][0], PKSB_mt_site['dir_inc'][0], PKSB_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')
#ipmag.plot_di_mean(PKSF_mt_site['dir_dec'][0], PKSF_mt_site['dir_inc'][0], PKSF_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')
#ipmag.plot_di_mean(PKSG_mt_site['dir_dec'][0], PKSG_mt_site['dir_inc'][0], PKSG_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(PKSH_mt_site['dir_dec'][0], PKSH_mt_site['dir_inc'][0], PKSH_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(PKSI_mt_site['dir_dec'][0], PKSI_mt_site['dir_inc'][0], PKSI_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(PKSJ_mt_site['dir_dec'][0], PKSJ_mt_site['dir_inc'][0], PKSJ_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(PKSK_mt_site['dir_dec'][0], PKSK_mt_site['dir_inc'][0], PKSK_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')
ipmag.plot_di_mean(WBEA_mt_site['dir_dec'][0], WBEA_mt_site['dir_inc'][0], WBEA_mt_site['dir_alpha95'][0], marker='o', markersize=10, color='purple')

site_mt_dec_list = [NWFA_mt_site['dir_dec'][0], NWFB_mt_site['dir_dec'][0], NWFC_mt_site['dir_dec'][0], PKQA_mt_site['dir_dec'][0], PKSB_mt_site['dir_dec'][0], PKSF_mt_site['dir_dec'][0], PKSG_mt_site['dir_dec'][0], PKSH_mt_site['dir_dec'][0], PKSI_mt_site['dir_dec'][0], PKSJ_mt_site['dir_dec'][0], PKSK_mt_site['dir_dec'][0], WBEA_mt_site['dir_dec'][0]]
site_mt_inc_list = [NWFA_mt_site['dir_inc'][0], NWFB_mt_site['dir_inc'][0], NWFC_mt_site['dir_inc'][0], PKQA_mt_site['dir_inc'][0], PKSB_mt_site['dir_inc'][0], PKSF_mt_site['dir_inc'][0], PKSG_mt_site['dir_inc'][0], PKSH_mt_site['dir_inc'][0], PKSI_mt_site['dir_inc'][0], PKSJ_mt_site['dir_inc'][0], PKSK_mt_site['dir_inc'][0], WBEA_mt_site['dir_inc'][0]]

all_mt_mean_dir = ipmag.fisher_mean(site_mt_dec_list, site_mt_inc_list)
# ipmag.plot_di_mean(all_mt_mean_dir['dec'], all_mt_mean_dir['inc'], all_mt_mean_dir['alpha95'], marker='s', markersize=50, color='r')
plt.savefig('code_output/Laos_site_mt_directions_mean.pdf', bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 21
#      19 all_mt_mean_dir = ipmag.fisher_mean(site_mt_dec_list, site_mt_inc_list)
#      20 # ipmag.plot_di_mean(all_mt_mean_dir['dec'], all_mt_mean_dir['inc'], all_mt_mean_dir['alpha95'], marker='s', markersize=50, color='r')
# ---> 21 plt.savefig('code_output/Laos_site_mt_directions_mean.pdf', bbox_inches='tight')
#      22 plt.show()
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# ...

# %%
all_mt_mean_dir_gc
# Out:
# {'dec': np.float64(157.36638924722632),
#  'inc': np.float64(-45.34288184388863),
#  'n': 8,
#  'r': np.float64(4.316701634163619),
#  'k': np.float64(1.900470530687101),
#  'alpha95': np.float64(57.02679261554893),
#  'csd': np.float64(58.75630127697247)}

# %%
plt.figure(figsize=(4,4))
ipmag.plot_net()
ipmag.plot_di_mean(NWFA_mt_site_gc['dir_dec'][0], NWFA_mt_site_gc['dir_inc'][0], NWFA_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(NWFB_mt_site_gc['dir_dec'][0], NWFB_mt_site_gc['dir_inc'][0], NWFB_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
# ipmag.plot_di_mean(NWFC_mt_site_gc['dir_dec'][0], NWFC_mt_site_gc['dir_inc'][0], NWFC_mt_site_gc['dir_alpha95'][0],
#                    marker='o', markersize=10, color='grey')
# ipmag.plot_di_mean(PKQA_mt_site_gc['dir_dec'][0], PKQA_mt_site_gc['dir_inc'][0], PKQA_mt_site_gc['dir_alpha95'][0],
#                    marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(PKSB_mt_site_gc['dir_dec'][0], PKSB_mt_site_gc['dir_inc'][0], PKSB_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
# ipmag.plot_di_mean(PKSF_mt_site_gc['dir_dec'][0], PKSF_mt_site_gc['dir_inc'][0], PKSF_mt_site_gc['dir_alpha95'][0],
#                    marker='o', markersize=10, color='grey')
# ipmag.plot_di_mean(PKSG_mt_site_gc['dir_dec'][0], PKSG_mt_site_gc['dir_inc'][0], PKSG_mt_site_gc['dir_alpha95'][0],
#                    marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(PKSH_mt_site_gc['dir_dec'][0], PKSH_mt_site_gc['dir_inc'][0], PKSH_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(PKSI_mt_site_gc['dir_dec'][0], PKSI_mt_site_gc['dir_inc'][0], PKSI_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(PKSJ_mt_site_gc['dir_dec'][0], PKSJ_mt_site_gc['dir_inc'][0], PKSJ_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(PKSK_mt_site_gc['dir_dec'][0], PKSK_mt_site_gc['dir_inc'][0], PKSK_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(WBEA_mt_site_gc['dir_dec'][0], WBEA_mt_site_gc['dir_inc'][0], WBEA_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')

site_mt_dec_gc_list = [
    NWFA_mt_site_gc['dir_dec'][0], NWFB_mt_site_gc['dir_dec'][0], 
    # NWFC_mt_site_gc['dir_dec'][0],
    # PKQA_mt_site_gc['dir_dec'][0],
    PKSB_mt_site_gc['dir_dec'][0], 
    # PKSF_mt_site_gc['dir_dec'][0],
    # PKSG_mt_site_gc['dir_dec'][0],
    PKSH_mt_site_gc['dir_dec'][0], PKSI_mt_site_gc['dir_dec'][0],
    PKSJ_mt_site_gc['dir_dec'][0], PKSK_mt_site_gc['dir_dec'][0], WBEA_mt_site_gc['dir_dec'][0]
]
site_mt_inc_gc_list = [
    NWFA_mt_site_gc['dir_inc'][0], NWFB_mt_site_gc['dir_inc'][0], 
    # NWFC_mt_site_gc['dir_inc'][0],
    # PKQA_mt_site_gc['dir_inc'][0],
    PKSB_mt_site_gc['dir_inc'][0], 
    # PKSF_mt_site_gc['dir_inc'][0],
    # PKSG_mt_site_gc['dir_inc'][0],
    PKSH_mt_site_gc['dir_inc'][0], PKSI_mt_site_gc['dir_inc'][0],
    PKSJ_mt_site_gc['dir_inc'][0], PKSK_mt_site_gc['dir_inc'][0], WBEA_mt_site_gc['dir_inc'][0]
]

all_mt_mean_dir_gc = ipmag.fisher_mean(site_mt_dec_gc_list, site_mt_inc_gc_list)
ipmag.plot_di_mean(all_mt_mean_dir_gc['dec'], all_mt_mean_dir_gc['inc'], all_mt_mean_dir_gc['alpha95'], marker='s', markersize=50, color='k')
# plt.savefig('code_output/DV_site_gc_mt_directions.pdf', bbox_inches='tight')
plt.show()

# %%
site_mt_dec_gc_list
# Out:
# [np.float64(10.3),
#  np.float64(75.6),
#  np.float64(190.5),
#  np.float64(178.9),
#  np.float64(48.8),
#  np.float64(175.4),
#  np.float64(196.1),
#  np.float64(166.2)]

# %%
all_mt_mean_dir_gc
# Out:
# {'dec': np.float64(157.36638924722632),
#  'inc': np.float64(-45.34288184388863),
#  'n': 8,
#  'r': np.float64(4.316701634163619),
#  'k': np.float64(1.900470530687101),
#  'alpha95': np.float64(57.02679261554893),
#  'csd': np.float64(58.75630127697247)}

# %%
plt.figure(figsize=(4,4))
ipmag.plot_net()
ipmag.plot_di_mean(NWFA_mt_site_gc['dir_dec'][0], NWFA_mt_site_gc['dir_inc'][0], NWFA_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(NWFB_mt_site_gc['dir_dec'][0], NWFB_mt_site_gc['dir_inc'][0], NWFB_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
# ipmag.plot_di_mean(NWFC_mt_site_gc['dir_dec'][0], NWFC_mt_site_gc['dir_inc'][0], NWFC_mt_site_gc['dir_alpha95'][0],
#                    marker='o', markersize=10, color='grey')
# ipmag.plot_di_mean(PKQA_mt_site_gc['dir_dec'][0], PKQA_mt_site_gc['dir_inc'][0], PKQA_mt_site_gc['dir_alpha95'][0],
#                    marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(PKSB_mt_site_gc['dir_dec'][0], PKSB_mt_site_gc['dir_inc'][0], PKSB_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
# ipmag.plot_di_mean(PKSF_mt_site_gc['dir_dec'][0], PKSF_mt_site_gc['dir_inc'][0], PKSF_mt_site_gc['dir_alpha95'][0],
#                    marker='o', markersize=10, color='grey')
# ipmag.plot_di_mean(PKSG_mt_site_gc['dir_dec'][0], PKSG_mt_site_gc['dir_inc'][0], PKSG_mt_site_gc['dir_alpha95'][0],
#                    marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(PKSH_mt_site_gc['dir_dec'][0], PKSH_mt_site_gc['dir_inc'][0], PKSH_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(PKSI_mt_site_gc['dir_dec'][0], PKSI_mt_site_gc['dir_inc'][0], PKSI_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(PKSJ_mt_site_gc['dir_dec'][0], PKSJ_mt_site_gc['dir_inc'][0], PKSJ_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(PKSK_mt_site_gc['dir_dec'][0], PKSK_mt_site_gc['dir_inc'][0], PKSK_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')
ipmag.plot_di_mean(WBEA_mt_site_gc['dir_dec'][0], WBEA_mt_site_gc['dir_inc'][0], WBEA_mt_site_gc['dir_alpha95'][0],
                   marker='o', markersize=10, color='grey')

site_mt_dec_gc_list = [
    NWFA_mt_site_gc['dir_dec'][0], NWFB_mt_site_gc['dir_dec'][0], 
    # NWFC_mt_site_gc['dir_dec'][0],
    # PKQA_mt_site_gc['dir_dec'][0],
    PKSB_mt_site_gc['dir_dec'][0], 
    # PKSF_mt_site_gc['dir_dec'][0],
    # PKSG_mt_site_gc['dir_dec'][0],
    PKSH_mt_site_gc['dir_dec'][0], PKSI_mt_site_gc['dir_dec'][0],
    PKSJ_mt_site_gc['dir_dec'][0], PKSK_mt_site_gc['dir_dec'][0], WBEA_mt_site_gc['dir_dec'][0]
]
site_mt_inc_gc_list = [
    NWFA_mt_site_gc['dir_inc'][0], NWFB_mt_site_gc['dir_inc'][0], 
    # NWFC_mt_site_gc['dir_inc'][0],
    # PKQA_mt_site_gc['dir_inc'][0],
    PKSB_mt_site_gc['dir_inc'][0], 
    # PKSF_mt_site_gc['dir_inc'][0],
    # PKSG_mt_site_gc['dir_inc'][0],
    PKSH_mt_site_gc['dir_inc'][0], PKSI_mt_site_gc['dir_inc'][0],
    PKSJ_mt_site_gc['dir_inc'][0], PKSK_mt_site_gc['dir_inc'][0], WBEA_mt_site_gc['dir_inc'][0]
]

all_mt_mean_dir_gc = ipmag.fisher_mean(site_mt_dec_gc_list, site_mt_inc_gc_list)
ipmag.plot_di_mean(all_mt_mean_dir_gc['dec'], all_mt_mean_dir_gc['inc'], all_mt_mean_dir_gc['alpha95'], marker='s', markersize=50, color='k')
# plt.savefig('code_output/DV_site_gc_mt_directions.pdf', bbox_inches='tight')
plt.show()

# %%
all_mt_mean_dir_gc,
# Out:
# {'dec': np.float64(157.36638924722632),
#  'inc': np.float64(-45.34288184388863),
#  'n': 8,
#  'r': np.float64(4.316701634163619),
#  'k': np.float64(1.900470530687101),
#  'alpha95': np.float64(57.02679261554893),
#  'csd': np.float64(58.75630127697247)}

# %%
NWFC_mt_site_gc
# Out:
#    site location                                            samples  \
# 0  NWFC     NWFC  NWFC-1B:NWFC-1C:NWFC-2B:NWFC-2C:NWFC-2D:NWFC-2...
#
#                                            specimens  dir_alpha95  \
# 0  NWFC-1B:NWFC-1C:NWFC-2B:NWFC-2C:NWFC-2D:NWFC-2...         31.2
#
#   dir_comp_name  dir_dec  dir_inc  dir_k  dir_n_samples  ...  analysts  \
# 0            mt     13.8     25.0    2.0             32  ...       NaN
#
#    criteria              software_packages   citations  \
# 0    ACCEPT  pmagpy-4.3.7: demag_gui.v.3.0  This study
#
#                                         method_codes  result_quality  vgp_dm  \
# 0  SO-CMD-NORTH:LP-DIR-T:DE-BFL:DA-DIR-GEO:LP-DC4...               g    33.5
#
#    vgp_dp  vgp_lat vgp_lon
# 0    18.0     76.4   204.0
#
# [1 rows x 28 columns]

# %% [markdown]
# ### conglomerate tests

# %% [markdown]
# The Watson (1956) test of a directional data set for randomness compares
#     the resultant vector (R) of a group of directions to values of Ro. If R
#     exceeds Ro, the null hypothesis of randomness is rejected. If R is less
#     than Ro, the null hypothesis of randomness is considered to not be rejected.
#
#     Parameters:
#         R : the resultant vector length of the directions
#         n : the number of directions
#
#     Returns:
#         **printed text** (text describing test result),
#         **result** (a dictionary with the Watson (1956) R values)
#     """
#     Ro_values = {5: {95: 3.50, 99: 4.02}, 6: {95: 3.85, 99: 4.48},
#                  7: {95: 4.18, 99: 4.89}, 8: {95: 4.48, 99: 5.26},
#                  9: {95: 4.76, 99: 5.61}, 10: {95: 5.03, 99: 5.94},
#                  11: {95: 5.29, 99: 6.25}, 12: {95: 5.52, 99: 6.55},
#                  13: {95: 5.75, 99: 6.84}, 14: {95: 5.98, 99: 7.11},
#                  15: {95: 6.19, 99: 7.36}, 16: {95: 6.40, 99: 7.60},
#                  17: {95: 6.60, 99: 7.84}, 18: {95: 6.79, 99: 8.08},
#                  19: {95: 6.98, 99: 8.33}, 20: {95: 7.17, 99: 8.55}}
#
#     if n < 5:
#         print('too few directions for a conglomerate test')
#         return
#
#     elif n < 21:
#         Ro_95 = Ro_values[n][95]
#         Ro_99 = Ro_values[n][99]
#
#     else:
#         Ro_95 = np.sqrt(7.815*(n/3))
#         Ro_99 = np.sqrt(11.345*(n/3))
#
#     print('R = ' + str(R))
#     print('Ro_95 = ' + str(Ro_95))
#     print('Ro_99 = ' + str(Ro_99))
#
#     if R < Ro_95:
#         print('This population "passes" a conglomerate test as the null hypothesis of randomness cannot be rejected at the 95% confidence level')
#
#     if R > Ro_95:
#         print(
#             'The null hypothesis of randomness can be rejected at the 95% confidence level')
#
#     if R > Ro_99:
#         print(
#             'The null hypothesis of randomness can be rejected at the 99% confidence level')
#
#     result = {'n': n, 'R': R, 'Ro_95': Ro_95, 'Ro_99': Ro_99}

# %% [markdown]
# ### conglomerate test by specimen WRONG!!

# %%
# NWFC
ipmag.conglomerate_test_Watson(NWFC_mt_site_gc['dir_r'][0], NWFC_mt_site_gc['dir_n_specimens_lines'][0])

# PKQA
ipmag.conglomerate_test_Watson(PKQA_mt_site['dir_r'][0], PKQA_mt_site['dir_n_specimens_lines'][0])

# PKSF
ipmag.conglomerate_test_Watson(PKSF_mt_site['dir_r'][0], PKSF_mt_site['dir_n_specimens_lines'][0])

# PKSG
ipmag.conglomerate_test_Watson(PKSG_mt_site['dir_r'][0], PKSG_mt_site['dir_n_specimens_lines'][0])
# Out:
# R = 13.2088
# Ro_95 = 9.130169768410662
# Ro_99 = 11.000606043911096
# The null hypothesis of randomness can be rejected at the 95% confidence level
# The null hypothesis of randomness can be rejected at the 99% confidence level
# R = 59.5751
# Ro_95 = 14.704251085995507
# Ro_99 = 17.71661179044496
# The null hypothesis of randomness can be rejected at the 95% confidence level
# The null hypothesis of randomness can be rejected at the 99% confidence level
# R = 32.6243
# Ro_95 = 16.85066764255945
# Ro_99 = 20.302750224210186
# The null hypothesis of randomness can be rejected at the 95% confidence level
# The null hypothesis of randomness can be rejected at the 99% confidence level
# R = 6.6837
# Ro_95 = 4.48
# Ro_99 = 5.26
# The null hypothesis of randomness can be rejected at the 95% confidence level
# The null hypothesis of randomness can be rejected at the 99% confidence level
# {'n': np.int64(8), 'R': np.float64(6.6837), 'Ro_95': 4.48, 'Ro_99': 5.26}

# %% [markdown]
# ### conglomerate test by each sample in a site

# %% [markdown]
# #### correct naming scheme for specimen, sample, site

# %%
import re

def extract_sample_name(specimen):
    # Matches 'NWFC-1B' -> 'NWFC-1', 'PKQA-2F' -> 'PKQA-2', etc.
    match = re.match(r'([A-Z]+-\d+)', specimen)
    return match.group(1) if match else specimen

conglomerate_sites = ['NWFC', 'PKQA', 'PKSF', 'PKSG']
sample_stats = []

for site in conglomerate_sites:
    print(f"\nChecking site: {site}")
    site_df = Laos_specimen_data[
        (Laos_specimen_data['location'] == site) &
        (Laos_specimen_data['dir_comp'] == 'mt') &
        (Laos_specimen_data['dir_tilt_correction'] == 0)
    ].copy()
    # Add true sample name column
    site_df['true_sample'] = site_df['specimen'].apply(extract_sample_name)
    print("Unique true samples:", site_df['true_sample'].unique())
    # Group by true sample
    for sample, sample_group in site_df.groupby('true_sample'):
        print(f"  Sample: {sample}, n_specimens: {sample_group['specimen'].nunique()}")
        specimen_means = []
        for specimen, spec_group in sample_group.groupby('specimen'):
            decs = spec_group['dir_dec'].tolist()
            incs = spec_group['dir_inc'].tolist()
            print(f"    Specimen: {specimen}, n_dirs: {len(decs)}")
            if len(decs) > 0 and len(incs) > 0:
                try:
                    stats = ipmag.fisher_mean(decs, incs)
                    specimen_means.append((stats['dec'], stats['inc']))
                except Exception as e:
                    print(f"      Error in fisher_mean for specimen {specimen}: {e}")
        if len(specimen_means) > 1:
            decs, incs = zip(*specimen_means)
            try:
                sample_stats_dict = ipmag.fisher_mean(decs, incs)
                sample_stats.append({
                    'site': site,
                    'sample': sample,
                    'n': sample_stats_dict['n'],
                    'r': sample_stats_dict['r'],
                    'dec': sample_stats_dict['dec'],
                    'inc': sample_stats_dict['inc'],
                    'k': sample_stats_dict['k'],
                    'alpha95': sample_stats_dict['alpha95'],
                    'csd': sample_stats_dict['csd']
                })
            except Exception as e:
                print(f"    Error in fisher_mean for sample {sample}: {e}")
        else:
            print(f"    Not enough specimen means for sample {sample} (n={len(specimen_means)})")

sample_stats_df = pd.DataFrame(sample_stats)
print("\nSample stats dataframe:")
print(sample_stats_df)
display(sample_stats_df)
# Out:
# Checking site: NWFC
# Unique true samples: ['NWFC-1' 'NWFC-2' 'NWFC-3' 'NWFC-4' 'NWFC-5' 'NWFC-6' 'NWFC-7' 'NWFC-8']
#   Sample: NWFC-1, n_specimens: 2
#     Specimen: NWFC-1B, n_dirs: 1
#     Specimen: NWFC-1C, n_dirs: 1
#   Sample: NWFC-2, n_specimens: 5
#     Specimen: NWFC-2B, n_dirs: 1
#     Specimen: NWFC-2C, n_dirs: 1
#     Specimen: NWFC-2D, n_dirs: 1
#     Specimen: NWFC-2E, n_dirs: 1
#     Specimen: NWFC-2F, n_dirs: 1
#   Sample: NWFC-3, n_specimens: 3
#     Specimen: NWFC-3B, n_dirs: 1
#     Specimen: NWFC-3C, n_dirs: 1
#     Specimen: NWFC-3D, n_dirs: 1
#   Sample: NWFC-4, n_specimens: 3
#     Specimen: NWFC-4B, n_dirs: 1
#     Specimen: NWFC-4C, n_dirs: 1
#     Specimen: NWFC-4D, n_dirs: 1
#   Sample: NWFC-5, n_specimens: 4
#     Specimen: NWFC-5B, n_dirs: 1
#     Specimen: NWFC-5C, n_dirs: 1
#     Specimen: NWFC-5D, n_dirs: 1
#     Specimen: NWFC-5E, n_dirs: 1
#   Sample: NWFC-6, n_specimens: 4
#     Specimen: NWFC-6B, n_dirs: 1
#     Specimen: NWFC-6C, n_dirs: 1
# ...

# %% [markdown]
# #### watson conglomerate test

# %%
# Watson conglomerate test for each site using sample means
for site in conglomerate_sites:
    site_samples = sample_stats_df[sample_stats_df['site'] == site]
    print(f"\nWatson test for site: {site}, n_samples: {len(site_samples)}")
    if len(site_samples) > 1:
        try:
            R_n_stats = ipmag.fisher_mean(site_samples['dec'].tolist(), site_samples['inc'].tolist())
            print(f"  R: {R_n_stats['r']}, n: {R_n_stats['n']}")
            ipmag.conglomerate_test_Watson(R_n_stats['r'], R_n_stats['n'])
        except Exception as e:
            print(f"  Error in Watson test for site {site}: {e}")
    else:
        print("  Not enough sample means for Watson test.")
# Out:
# Watson test for site: NWFC, n_samples: 8
#   R: 3.3748112153847227, n: 8
# R = 3.3748112153847227
# Ro_95 = 4.48
# Ro_99 = 5.26
# This population "passes" a conglomerate test as the null hypothesis of randomness cannot be rejected at the 95% confidence level
#
# Watson test for site: PKQA, n_samples: 10
#   R: 7.239116815709265, n: 10
# R = 7.239116815709265
# Ro_95 = 5.03
# Ro_99 = 5.94
# The null hypothesis of randomness can be rejected at the 95% confidence level
# The null hypothesis of randomness can be rejected at the 99% confidence level
#
# Watson test for site: PKSF, n_samples: 10
#   R: 4.725283760003103, n: 10
# R = 4.725283760003103
# Ro_95 = 5.03
# Ro_99 = 5.94
# This population "passes" a conglomerate test as the null hypothesis of randomness cannot be rejected at the 95% confidence level
#
# Watson test for site: PKSG, n_samples: 8
#   R: 6.684775935241685, n: 8
# R = 6.684775935241685
# Ro_95 = 4.48
# Ro_99 = 5.26
# ...

# %%
# Custom PKQA sample grouping for Watson test
PKQA_sample_map = {
    'PKQA-1': 'PKQA-A', 'PKQA-2': 'PKQA-A',      # Sample 1
    'PKQA-3': 'PKQA-B', 'PKQA-4': 'PKQA-B',      # Sample 2
    'PKQA-5': 'PKQA-C', 'PKQA-6': 'PKQA-C',      # Sample 3
    'PKQA-7': 'PKQA-D', 'PKQA-8': 'PKQA-D', 'PKQA-9': 'PKQA-D', 'PKQA-0': 'PKQA-D'  # Sample 4
}

pkqa_df = Laos_specimen_data[
    (Laos_specimen_data['location'] == 'PKQA') &
    (Laos_specimen_data['dir_comp'] == 'mt') &
    (Laos_specimen_data['dir_tilt_correction'] == 0)
].copy()

pkqa_df['physical_sample'] = pkqa_df['specimen'].apply(lambda x: PKQA_sample_map.get(extract_sample_name(x), None))
pkqa_df = pkqa_df[pkqa_df['physical_sample'].notnull()]

pkqa_sample_means = []
for sample, group in pkqa_df.groupby('physical_sample'):
    specimen_means = []
    for specimen, spec_group in group.groupby('specimen'):
        decs = spec_group['dir_dec'].tolist()
        incs = spec_group['dir_inc'].tolist()
        if len(decs) > 0 and len(incs) > 0:
            stats = ipmag.fisher_mean(decs, incs)
            specimen_means.append((stats['dec'], stats['inc']))
    if len(specimen_means) > 1:
        decs, incs = zip(*specimen_means)
        sample_stats = ipmag.fisher_mean(decs, incs)
        pkqa_sample_means.append((sample_stats['dec'], sample_stats['inc']))

# Watson test for PKQA using physical samples
if len(pkqa_sample_means) > 1:
    decs, incs = zip(*pkqa_sample_means)
    R_n_stats = ipmag.fisher_mean(decs, incs)
    print(f"\nWatson test for PKQA (physical samples), n_samples: {len(pkqa_sample_means)}")
    print(f"  R: {R_n_stats['r']}, n: {R_n_stats['n']}")
    ipmag.conglomerate_test_Watson(R_n_stats['r'], R_n_stats['n'])
else:
    print("Not enough physical samples for Watson test (PKQA).")
# Out:
# Watson test for PKQA (physical samples), n_samples: 4
#   R: 2.802004387223032, n: 4
# too few directions for a conglomerate test

# %%
# change watson to work with n=4
def watson_conglomerate_test_n4(R, n):
    Ro_values = {4: {95: 3.18, 99: 3.65}, 5: {95: 3.50, 99: 4.02}, 6: {95: 3.85, 99: 4.48},
                 7: {95: 4.18, 99: 4.89}, 8: {95: 4.48, 99: 5.26}, 9: {95: 4.76, 99: 5.61},
                 10: {95: 5.03, 99: 5.94}, 11: {95: 5.29, 99: 6.25}, 12: {95: 5.52, 99: 6.55},
                 13: {95: 5.75, 99: 6.84}, 14: {95: 5.98, 99: 7.11}, 15: {95: 6.19, 99: 7.36},
                 16: {95: 6.40, 99: 7.60}, 17: {95: 6.60, 99: 7.84}, 18: {95: 6.79, 99: 8.08},
                 19: {95: 6.98, 99: 8.33}, 20: {95: 7.17, 99: 8.55}}
    if n < 4:
        print('too few directions for a conglomerate test')
        return
    elif n < 21:
        Ro_95 = Ro_values[n][95]
        Ro_99 = Ro_values[n][99]
    else:
        Ro_95 = np.sqrt(7.815*(n/3))
        Ro_99 = np.sqrt(11.345*(n/3))
    print('R = ' + str(R))
    print('Ro_95 = ' + str(Ro_95))
    print('Ro_99 = ' + str(Ro_99))
    if R < Ro_95:
        print('This population "passes" a conglomerate test as the null hypothesis of randomness cannot be rejected at the 95% confidence level')
    if R > Ro_95:
        print('The null hypothesis of randomness can be rejected at the 95% confidence level')
    if R > Ro_99:
        print('The null hypothesis of randomness can be rejected at the 99% confidence level')
    result = {'n': n, 'R': R, 'Ro_95': Ro_95, 'Ro_99': Ro_99}
    return result

# Use this function for your PKQA Watson test
if len(pkqa_sample_means) >= 2:
    decs, incs = zip(*pkqa_sample_means)
    R_n_stats = ipmag.fisher_mean(decs, incs)
    print(f"\nWatson test for PKQA (physical samples), n_samples: {len(pkqa_sample_means)}")
    print(f"  R: {R_n_stats['r']}, n: {R_n_stats['n']}")
    watson_conglomerate_test_n4(R_n_stats['r'], R_n_stats['n'])
else:
    print("Not enough physical samples for Watson test (PKQA).")
# Out:
# Watson test for PKQA (physical samples), n_samples: 4
#   R: 2.802004387223032, n: 4
# R = 2.802004387223032
# Ro_95 = 3.18
# Ro_99 = 3.65
# This population "passes" a conglomerate test as the null hypothesis of randomness cannot be rejected at the 95% confidence level

# %%
import matplotlib.lines as mlines

for site in conglomerate_sites:
    site_samples = sample_stats_df[sample_stats_df['site'] == site]
    if len(site_samples) > 1:
        site_mean_stats = ipmag.fisher_mean(site_samples['dec'].tolist(), site_samples['inc'].tolist())
        plt.figure(figsize=(4,4))
        ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
        ipmag.plot_net()
        # Plot sample means with confidence ellipses
        for _, row in site_samples.iterrows():
            ipmag.plot_di_mean(row['dec'], row['inc'], row['alpha95'], marker='o', markersize=10, color='purple', zorder=10)
        # Plot site mean with confidence ellipse
        ipmag.plot_di_mean(site_mean_stats['dec'], site_mean_stats['inc'], site_mean_stats['alpha95'], marker='o', markersize=20, color='orange', zorder=20)
        stats_text = (
            f"{site} site mean\n"
            f"n = {site_mean_stats['n']}\n"
            f"dec = {site_mean_stats['dec']:.1f}\n"
            f"inc = {site_mean_stats['inc']:.1f}\n"
            f"alpha95 = {site_mean_stats['alpha95']:.1f}\n"
            f"k = {site_mean_stats['k']:.1f}"
        )
        # Custom legend handles
        star_handle = mlines.Line2D([], [], color='r', marker='*', linestyle='None', markersize=15, label='Present day field')
        purple_handle = mlines.Line2D([], [], color='purple', marker='o', linestyle='None', markersize=10, label='Sample mean (Fisher ellipse)')
        orange_handle = mlines.Line2D([], [], color='orange', marker='o', linestyle='None', markersize=15, label='Site mean (Fisher ellipse)')
        plt.legend(handles=[star_handle, purple_handle, orange_handle], title=stats_text, loc='lower left', fontsize=10, frameon=True)
        plt.title(f"{site} sample means and site mean")
        plt.show()
    else:
        print(f"{site}: Not enough sample means to plot.")

# %%
import matplotlib.lines as mlines
import re

def extract_sample_name(specimen):
    # Matches 'PKQA-1A' -> 'PKQA-1', 'PKQA-2F' -> 'PKQA-2', etc.
    match = re.match(r'([A-Z]+-\d+)', specimen)
    return match.group(1) if match else specimen

# Custom PKQA sample grouping for Watson test
PKQA_sample_map = {
    'PKQA-1': 'PKQA-A', 'PKQA-2': 'PKQA-A',
    'PKQA-3': 'PKQA-B', 'PKQA-4': 'PKQA-B',
    'PKQA-5': 'PKQA-C', 'PKQA-6': 'PKQA-C',
    'PKQA-7': 'PKQA-D', 'PKQA-8': 'PKQA-D', 'PKQA-9': 'PKQA-D', 'PKQA-0': 'PKQA-D'
}

pkqa_df = Laos_specimen_data[
    (Laos_specimen_data['location'] == 'PKQA') &
    (Laos_specimen_data['dir_comp'] == 'mt') &
    (Laos_specimen_data['dir_tilt_correction'] == 0)
].copy()
pkqa_df['physical_sample'] = pkqa_df['specimen'].apply(lambda x: PKQA_sample_map.get(extract_sample_name(x), None))
pkqa_df = pkqa_df[pkqa_df['physical_sample'].notnull()]

# Calculate sample means for each boulder
pkqa_sample_stats = []
for sample, group in pkqa_df.groupby('physical_sample'):
    specimen_means = []
    for specimen, spec_group in group.groupby('specimen'):
        decs = spec_group['dir_dec'].tolist()
        incs = spec_group['dir_inc'].tolist()
        if len(decs) > 0 and len(incs) > 0:
            stats = ipmag.fisher_mean(decs, incs)
            specimen_means.append((stats['dec'], stats['inc']))
    if len(specimen_means) > 1:
        decs, incs = zip(*specimen_means)
        sample_stats = ipmag.fisher_mean(decs, incs)
        pkqa_sample_stats.append({
            'sample': sample,
            'n': sample_stats['n'],
            'dec': sample_stats['dec'],
            'inc': sample_stats['inc'],
            'alpha95': sample_stats['alpha95'],
            'k': sample_stats['k']
        })

pkqa_sample_stats_df = pd.DataFrame(pkqa_sample_stats)

# Calculate site mean from boulder means
if len(pkqa_sample_stats_df) > 1:
    site_mean_stats = ipmag.fisher_mean(pkqa_sample_stats_df['dec'].tolist(), pkqa_sample_stats_df['inc'].tolist())
else:
    site_mean_stats = None

plt.figure(figsize=(4,4))
ipmag.plot_di(Laos_pdf_dec, Laos_pdf_inc, marker='*', markersize=100, color='r', zorder=100)
ipmag.plot_net()
# Plot sample (boulder) means
for _, row in pkqa_sample_stats_df.iterrows():
    ipmag.plot_di_mean(row['dec'], row['inc'], row['alpha95'], marker='o', markersize=15, color='purple', zorder=10)
# Plot site mean
if site_mean_stats:
    ipmag.plot_di_mean(site_mean_stats['dec'], site_mean_stats['inc'], site_mean_stats['alpha95'], marker='o', markersize=15, color='orange', zorder=20)
    stats_text = (
        f"    PKQA\n"
        f"    n = {site_mean_stats['n']}\n"
        f"    dec = {site_mean_stats['dec']:.1f}\n"
        f"    inc = {site_mean_stats['inc']:.1f}\n"
        f"    alpha95 = {site_mean_stats['alpha95']:.1f}\n"
        f"    k = {site_mean_stats['k']:.1f}"
    )
else:
    stats_text = "    Not enough boulder means for site mean"

# Custom legend handles
star_handle = mlines.Line2D([], [], color='r', marker='*', linestyle='None', markersize=10, label='Present day field')
purple_handle = mlines.Line2D([], [], color='purple', marker='o', linestyle='None', markersize=10,
                              markeredgewidth=2, markeredgecolor='purple', markerfacecolor='white',
                              label='Boulder mean (Fisher)')
orange_handle = mlines.Line2D([], [], color='orange', marker='o', linestyle='None', markersize=10,
                              markeredgewidth=2, markeredgecolor='orange', markerfacecolor='white',
                              label='Site mean (Fisher)')
legend = plt.legend(handles=[star_handle, purple_handle, orange_handle], title=stats_text, loc='lower left', fontsize=10, frameon=True)
legend._legend_box.align = "left"
plt.title("PKQA boulder means and site mean")
plt.show()
